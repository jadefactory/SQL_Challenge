# %%
from PIL import Image

# %%
Image.open('july_active_user.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1405x683 at 0x7FD05D4A2190>

# %% [markdown]
# #### 태블로 퍼블릭 공유 링크
#
# https://public.tableau.com/views/July_ActiveUser/7?:language=ko-KR&publish=yes&:display_count=n&:origin=viz_share_link

# %% [markdown]
# #### DAU 분석 결과
#
# - 추세선을 그렸을 때 Active User 수가 증가하는 추세임을 알 수 있음.
# - 요일별 반복적인 이용자 수 증감 패턴이 나타나는 것도 확인할 수 있음.
