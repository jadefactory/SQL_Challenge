# %%
from PIL import Image

# %%
Image.open('July_Revenue.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1815x839 at 0x7F1CCA70A550>

# %% [markdown]
# #### 태블로 퍼블릭 공유 링크
#
# https://public.tableau.com/views/July_Revenue/July_Revenue?:language=ko-KR&publish=yes&:display_count=n&:origin=viz_share_link

# %% [markdown]
# #### Daily Revenue 분석 결과
#
# - 추세선을 그렸을 때 일일 매출액이 증가하는 추세임을 알 수 있음.
# - 요일별 반복적인 이용자 수 증감 패턴이 나타나는 것도 확인할 수 있음.
